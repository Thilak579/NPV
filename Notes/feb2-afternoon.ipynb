# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
file=pd.read_csv('C:\\Users\\Thilak\\Desktop\\Automobile.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ae53da38f86f> in <module>
# ----> 1 file=pd.read_csv('C:\\Users\\Thilak\\Desktop\\Automobile.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
pwd

# %%
file
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
file.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
file.head(10)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
# 7          1                168         audi       gas        std
# 8          1                158         audi       gas      turbo
# 9          2                192          bmw       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# ...

# %%
file.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
file.tail(10)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
file.shape
# Out:
# (201, 26)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
file.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %%
file.index
# Out:
# RangeIndex(start=0, stop=201, step=1)

# %%
file.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
file.values
# Out:
# array([[3, 168, 'alfa-romero', ..., 21, 27, 13495],
#        [3, 168, 'alfa-romero', ..., 21, 27, 16500],
#        [1, 168, 'alfa-romero', ..., 19, 26, 16500],
#        ...,
#        [-1, 95, 'volvo', ..., 18, 23, 21485],
#        [-1, 95, 'volvo', ..., 26, 27, 22470],
#        [-1, 95, 'volvo', ..., 19, 25, 22625]], dtype=object)

# %%
file.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
file['make'].head(10)
# Out:
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# 5           audi
# 6           audi
# 7           audi
# 8           audi
# 9            bmw
# Name: make, dtype: object

# %%
file[['make','price']].head(10)
# Out:
#           make  price
# 0  alfa-romero  13495
# 1  alfa-romero  16500
# 2  alfa-romero  16500
# 3         audi  13950
# 4         audi  17450
# 5         audi  15250
# 6         audi  17710
# 7         audi  18920
# 8         audi  23875
# 9          bmw  16430

# %%
file.loc[0]
# Out:
# symboling                        3
# normalized_losses              168
# make                   alfa-romero
# fuel_type                      gas
# aspiration                     std
# number_of_doors                two
# body_style             convertible
# drive_wheels                   rwd
# engine_location              front
# wheel_base                    88.6
# length                       168.8
# width                         64.1
# height                        48.8
# curb_weight                   2548
# engine_type                   dohc
# number_of_cylinders           four
# engine_size                    130
# fuel_system                   mpfi
# bore                          3.47
# stroke                        2.68
# compression_ratio                9
# horsepower                     111
# peak_rpm                      5000
# city_mpg                        21
# highway_mpg                     27
# price                        13495
# Name: 0, dtype: object

# %%
file.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
file['body_style'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-275473a05847> in <module>
# ----> 1 file['body_style'].counts()
#
# NameError: name 'file' is not defined

# %%
file['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
file['fuel-system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
file['fuel-system'].nunique()
# Out:
# 8

# %%
file['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
file['make'].nunique()
# Out:
# 22

# %%
# how many cars in your dataset run on gas/diesel?

# %%
file['fuel_type'].value_counts()
# Out:
# gas       181
# diesel     20
# Name: fuel_type, dtype: int64

# %% [raw]
# The total no of cars that run on gas is 185 and diesel is 20

# %%
Which is the most expensive car in your dataset? What is the price in dollars?
# Out:
# Object `dollars` not found.

# %%
Which is the most expensive car in your dataset? What is the price in dollars

# %%
file['price'].max()
# Out:
# 45400

# %%
file[file['price']==45400]['make']
# Out:
# 74    mercedes-benz
# Name: make, dtype: object

# %% [markdown]
# the most expensive car in my dataset is merc with 45400 dollars.

# %% [markdown]
# How many cars have the engine located at the front?

# %%
file['engine-location'].value_counts()
# Out:
# front    202
# rear       3
# Name: engine-location, dtype: int64

# %%
file[file['engine-location']=='front'].count()
# Out:
# symboling            202
# normalized-losses    202
# make                 202
# fuel-type            202
# aspiration           202
# num-of-doors         202
# body-style           202
# drive-wheels         202
# engine-location      202
# wheel-base           202
# length               202
# width                202
# height               202
# curb-weight          202
# engine-type          202
# num-of-cylinders     202
# engine-size          202
# fuel-system          202
# bore                 202
# stroke               202
# compression-ratio    202
# horsepower           202
# peak-rpm             202
# city-mpg             202
# highway-mpg          202
# price                202
# dtype: int64

# %% [markdown]
# how many unique engine types are there in this dataset?

# %%
file['engine-type'].nunique()
# Out:
# 7

# %% [markdown]
# which is the most expensive jaguar? what is the price? what is the fuel system?

# %%
file[file['make']=='jaguar']['price'].max()
# Out:
# 36000

# %%
file[(file['make']=='jaguar')  & (file['price']==36000)][['fuel_system','price']]
# Out:
#    fuel_system  price
# 46        mpfi  36000

# %%
file.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
file.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
pd.crosstab(file['make'],file['fuel_type'])# only categorical data
# Out:
# fuel_type      diesel  gas
# make
# alfa-romero         0    3
# audi                0    6
# bmw                 0    8
# chevrolet           0    3
# dodge               0    9
# honda               0   13
# isuzu               0    2
# jaguar              0    3
# mazda               2   15
# mercedes-benz       4    4
# mercury             0    1
# mitsubishi          0   13
# nissan              1   17
# peugot              5    6
# plymouth            0    7
# porsche             0    4
# renault             0    2
# saab                0    6
# subaru              0   12
# toyota              3   29
# volkswagen          4    8
# volvo               1   10

# %%
file['fuel-type'].map({'gas':'gasoline','diesel':'diesel_system'})
# Out:
# 0           gasoline
# 1           gasoline
# 2           gasoline
# 3           gasoline
# 4           gasoline
#            ...
# 200         gasoline
# 201         gasoline
# 202         gasoline
# 203    diesel_system
# 204         gasoline
# Name: fuel-type, Length: 205, dtype: object

# %%
file['wheel-base'].astype('complex128')
# Out:
# 0       88.600000+0.000000j
# 1       88.600000+0.000000j
# 2       94.500000+0.000000j
# 3       99.800000+0.000000j
# 4       99.400000+0.000000j
#                ...
# 200    109.100000+0.000000j
# 201    109.100000+0.000000j
# 202    109.100000+0.000000j
# 203    109.100000+0.000000j
# 204    109.100000+0.000000j
# Name: wheel-base, Length: 205, dtype: complex128

# %%
find out the 10 cheapest cars in the datset with prices?
# Out:
# Object `prices` not found.

# %%
find out the 10 cheapest cars in the datset with prices

# %%
file['price'].sort_values(ascending=True).head(10)
# Out:
# 134    5118.0
# 17     5151.0
# 47     5195.0
# 146    5348.0
# 73     5389.0
# 31     5399.0
# 86     5499.0
# 20     5572.0
# 115    5572.0
# 48     6095.0
# Name: price, dtype: float64

# %%
file.sort_values('price',ascending=True).head(10)# by default data is arranged in ascending order
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 134          2                 83      subaru       gas        std
# 17           2                121   chevrolet       gas        std
# 47           1                104       mazda       gas        std
# 146          1                 87      toyota       gas        std
# 73           2                161  mitsubishi       gas        std
# 31           1                101       honda       gas        std
# 86           1                128      nissan       gas        std
# 115          1                119    plymouth       gas        std
# 20           1                118       dodge       gas        std
# 48           1                104       mazda       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 134             two  hatchback          fwd           front        93.7  ...
# ...

# %% [markdown]
# change the data type of price column into int 32 and make it permanent

# %%
file['price']=file['price'].astype('int32')

# %%
file['price'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# Q : please map the no of doors- two:2 and four:4 permanently.

# %%
file['num-of-doors']=file['num-of-doors'].map({'two':2,'four':4})

# %%
file.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration  \
# 0          3                 ?  alfa-romero       gas        std
# 1          3                 ?  alfa-romero       gas        std
# 2          1                 ?  alfa-romero       gas        std
# 3          2               164         audi       gas        std
# 4          2               164         audi       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           2.0  convertible          rwd           front        88.6  ...
# 1           2.0  convertible          rwd           front        88.6  ...
# 2           2.0    hatchback          rwd           front        94.5  ...
# 3           4.0        sedan          fwd           front        99.8  ...
# 4           4.0        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
file.groupby('make').mean()# aggregate function-min,max,mean
# Out:
#                symboling  normalized_losses  wheel_base      length  \
# make
# alfa-romero     2.333333         168.000000   90.566667  169.600000
# audi            1.500000         162.166667  102.733333  184.766667
# bmw             0.375000         169.500000  103.162500  184.500000
# chevrolet       1.000000         100.000000   92.466667  151.933333
# dodge           1.000000         133.444444   95.011111  160.988889
# honda           0.615385         103.000000   94.330769  160.769231
# isuzu           1.000000         110.000000   95.150000  171.650000
# jaguar          0.000000         125.000000  109.333333  196.966667
# mazda           1.117647         122.529412   97.017647  170.805882
# mercedes-benz   0.000000         114.500000  110.925000  195.262500
# mercury         1.000000         140.000000  102.700000  178.400000
# mitsubishi      1.846154         144.538462   95.353846  168.030769
# nissan          1.000000         135.166667   95.722222  170.988889
# ...
