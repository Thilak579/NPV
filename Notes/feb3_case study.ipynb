# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('Automobile.csv')

# %%
data.head(10)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
# 7          1                168         audi       gas        std
# 8          1                158         audi       gas      turbo
# 9          2                192          bmw       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# ...

# %%
data.shape
# Out:
# (201, 26)

# %%
data.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
data.sample(5)
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 106          0                161      peugot       gas        std
# 5            2                161        audi       gas        std
# 143          0                 89      subaru       gas        std
# 162          1                168      toyota       gas        std
# 185          3                137  volkswagen       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 106            four        wagon          rwd           front       114.2
# 5               two        sedan          fwd           front        99.8
# 143            four        wagon          fwd           front        97.0
# 162             two    hatchback          rwd           front        94.5
# 185             two  convertible          fwd           front        94.5
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
What is the relationship between horsepower and price?

# %%
sns.scatterplot(x='horsepower',y='price',data=data,color='g')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
what is the relationship between length of a car and price?

# %%
sns.scatterplot(x='length',y='price',data=data,color='r')
# Out:
# <AxesSubplot:xlabel='length', ylabel='price'>

# %%
what is the rel between city mpg and price?

# %%
data.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
sns.scatterplot(x='city_mpg',y='price',data=data)
# Out:
# <AxesSubplot:xlabel='city_mpg', ylabel='price'>

# %%
data['fuel_type'].value_counts()
# Out:
# gas       181
# diesel     20
# Name: fuel_type, dtype: int64

# %%
sns.countplot(x='fuel_type',data=data)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='count'>

# %%
sns.barplot(y='body_style',x='price',data=data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='body_style'>

# %%
plt.figure(figsize=(10,11))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#                    symboling  normalized_losses  wheel_base    length  \
# symboling           1.000000           0.474993   -0.535987 -0.365404
# normalized_losses   0.474993           1.000000    0.007815  0.103659
# wheel_base         -0.535987           0.007815    1.000000  0.876024
# length             -0.365404           0.103659    0.876024  1.000000
# width              -0.242423           0.153752    0.814507  0.857170
# height             -0.550160          -0.335476    0.590742  0.492063
# curb_weight        -0.233118           0.178547    0.782097  0.880665
# engine_size        -0.110581           0.174788    0.572027  0.685025
# bore               -0.146355           0.007498    0.495210  0.610324
# stroke              0.018373           0.062666    0.148239  0.116745
# compression_ratio  -0.182196          -0.120846    0.250313  0.159733
# horsepower          0.075287           0.276665    0.372607  0.577923
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
sns.distplot(data['price'],kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x='fuel_type',y='price',data=data)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='price'>

# %%
#whiskers Q1 quartile q2 median(middle value) q3 75%

# %%
sns.scatterplot(x='horsepower',y='price',data=data,hue= 'engine_location',cmap=)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>
